# %%
import torch
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cuda'

# %%
with open("1661-0.txt", 'r') as f:
      text = f.read()

# %%
import re
def clean_text(text: str) -> str:
    if isinstance(text, str):
        text = re.sub(r'http\S+|www\.\S+', '', text)   # remove URLs
        text = re.sub(r'[^a-zA-Z\s]', '', text)        # remove punctuation & numbers
        text = re.sub(r'\n+', ' ', text)                # remove newlines → single space
        text = re.sub(r'\s+', ' ', text)                # collapse multiple spaces
        return text.lower().strip()
    return text

text = clean_text(text)

# %% [markdown]
# ### Tokenize

# %%
import nltk
nltk.download("punkt")
nltk.download("punkt_tab")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
from nltk import word_tokenize

tokens = word_tokenize(text)

# %%
from collections import Counter

vocab = {
      "<UNK>":0
}

for token in Counter(tokens).keys():
      if token not in vocab:
            vocab[token] = len(vocab)

# %%
## Text to numeric
def text_to_indices(sentence, vocab):
      numeric_sentence = []

      for token in sentence:
            if token in vocab:
                  numeric_sentence.append(vocab[token])
            else:
                  numeric_sentence.append(vocab['<UNK>'])
      return numeric_sentence

indices = text_to_indices(word_tokenize(text), vocab)

# %%
def build_sequence(indices, seq_len = 50):
      x = []
      y = []

      for i in range(len(indices) - seq_len):
            input_seq = indices[i : i + seq_len]
            target = indices[i + seq_len]

            x.append(input_seq)
            y.append(target)
      return x, y

x, y = build_sequence(indices, seq_len=50)

# %%
import torch
from torch.utils.data import Dataset, DataLoader

# %%
class CustomDataSet(Dataset):

      def __init__(self, x, y):
            self.X = torch.tensor(x, dtype=torch.long)
            self.Y = torch.tensor(y, dtype=torch.long)

      def __len__(self):
            return len(self.X)

      def __getitem__(self, index):
            return self.X[index], self.Y[index]

# %%
datasets = CustomDataSet(x, y)

# %%
datasets[0][1]
# Out:
# tensor(13)

# %%
dataloader = DataLoader(datasets, batch_size=32, shuffle=True)

# %%
import torch.nn as nn
import torch.optim as optim

# %%
class LSTMModel(nn.Module):

      def __init__(self, vocab_size):
            super().__init__()
            self.embedding = nn.Embedding(vocab_size, 100)
            self.lstm = nn.LSTM(100, 32, batch_first=True)
            self.linear = nn.Linear(32, vocab_size)

      def forward(self, x):
            embedded_input = self.embedding(x)
            intermediate_hidden_state, (final_hidden_state, final_cell_states) = self.lstm(embedded_input)
            return self.linear(final_hidden_state.squeeze(0))

# %%
model = LSTMModel(len(vocab))
model.to(device)
# Out:
# LSTMModel(
#   (embedding): Embedding(8594, 100)
#   (lstm): LSTM(100, 32, batch_first=True)
#   (linear): Linear(in_features=32, out_features=8594, bias=True)
# )

# %%
epochs = 50
learning_rate = 0.001

loss_fnc = nn.CrossEntropyLoss()
optimizer = optim.Adam(params=model.parameters(), lr=learning_rate)

for i in range(epochs):
      total_loss = 0
      for input, actual_output in dataloader:
            input = input.to(device)
            actual_output = actual_output.to(device)

            optimizer.zero_grad()
            output = model(input)

            loss = loss_fnc(output, actual_output)

            loss.backward()

            optimizer.step()
            total_loss += loss.item()
      print(f"Epochs {i}: Loss {total_loss / len(dataloader)}")
# Out:
# Epochs 0: Loss 6.386575116083123
# Epochs 1: Loss 5.7160300298273885
# Epochs 2: Loss 5.41416265923328
# Epochs 3: Loss 5.193742117901655
# Epochs 4: Loss 5.019872106917917
# Epochs 5: Loss 4.877274242591971
# Epochs 6: Loss 4.753685249325205
# Epochs 7: Loss 4.644342228086879
# Epochs 8: Loss 4.544764237080109
# Epochs 9: Loss 4.455549458366835
# Epochs 10: Loss 4.374382374895833
# Epochs 11: Loss 4.296650808186954
# Epochs 12: Loss 4.2259296085763145
# Epochs 13: Loss 4.161649037145873
# Epochs 14: Loss 4.100361524982918
# Epochs 15: Loss 4.042763699513947
# Epochs 16: Loss 3.989478316386588
# Epochs 17: Loss 3.93972620430129
# Epochs 18: Loss 3.8914583258290882
# Epochs 19: Loss 3.8460643990115084
# Epochs 20: Loss 3.8065319355930014
# Epochs 21: Loss 3.76493759379634
# Epochs 22: Loss 3.7271606756364255
# Epochs 23: Loss 3.6913932773454903
# Epochs 24: Loss 3.660042006959512
# Epochs 25: Loss 3.6272082411866586
# Epochs 26: Loss 3.5963746218400177
# ...

# %%
def prediction(model, vocab, text, device, seq_len=50):
      model.eval()
      tokens = word_tokenize(clean_text(text))
      input  = text_to_indices(tokens, vocab)
      input  = input[-seq_len:]

      x = torch.tensor(input, dtype=torch.long).unsqueeze(0).to(device)

      with torch.no_grad():
            output = model(x)
            value, index = torch.max(output, dim=1)
            return text + " " + list(vocab.keys())[index.item()]

# %%
prediction(model, vocab, "what if", device)
# Out:
# 'what if spaulding'

# %%
num_tokens = 10
input_text = "how are"

for i in range(num_tokens):
      output_text = prediction(model, vocab, input_text, device)
      print(output_text)
      input_text = output_text
# Out:
# how are north
# how are north clump
# how are north clump of
# how are north clump of laurel
# how are north clump of laurel bushes
# how are north clump of laurel bushes i
# how are north clump of laurel bushes i had
# how are north clump of laurel bushes i had no
# how are north clump of laurel bushes i had no doubt
# how are north clump of laurel bushes i had no doubt that
